# %%
# %pip install fastapi uvicorn structlog requests pydantic azure-monitor-opentelemetry
# Out:
# Requirement already satisfied: fastapi in /databricks/python3/lib/python3.12/site-packages (0.128.0)
# Requirement already satisfied: uvicorn in /databricks/python3/lib/python3.12/site-packages (0.40.0)
# Collecting structlog
#   Downloading structlog-26.1.0-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: requests in /databricks/python3/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: pydantic in /databricks/python3/lib/python3.12/site-packages (2.10.6)
# Collecting azure-monitor-opentelemetry
#   Downloading azure_monitor_opentelemetry-1.8.8-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /databricks/python3/lib/python3.12/site-packages (from fastapi) (0.50.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /databricks/python3/lib/python3.12/site-packages (from fastapi) (4.12.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /databricks/python3/lib/python3.12/site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: click>=7.0 in /databricks/python3/lib/python3.12/site-packages (from uvicorn) (8.1.8)
# Requirement already satisfied: h11>=0.8 in /databricks/python3/lib/python3.12/site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests) (2025.4.26)
# Requirement already satisfied: annotated-types>=0.6.0 in /databricks/python3/lib/python3.12/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /databricks/python3/lib/python3.12/site-packages (from pydantic) (2.27.2)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /databricks/python3/lib/python3.12/site-packages (from azure-monitor-opentelemetry) (1.37.0)
# Collecting azure-core-tracing-opentelemetry~=1.0.0b11 (from azure-monitor-opentelemetry)
#   Downloading azure_core_tracing_opentelemetry-1.0.0b13-py3-none-any.whl.metadata (11 kB)
# Collecting azure-monitor-opentelemetry-exporter~=1.0.0b52 (from azure-monitor-opentelemetry)
#   Downloading azure_monitor_opentelemetry_exporter-1.0.0b53-py2.py3-none-any.whl.metadata (33 kB)
# Collecting opentelemetry-sdk==1.40 (from azure-monitor-opentelemetry)
#   Downloading opentelemetry_sdk-1.40.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-instrumentation-django==0.61b0 (from azure-monitor-opentelemetry)
#   Downloading opentelemetry_instrumentation_django-0.61b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi==0.61b0 (from azure-monitor-opentelemetry)
#   Downloading opentelemetry_instrumentation_fastapi-0.61b0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-flask==0.61b0 (from azure-monitor-opentelemetry)
#   Downloading opentelemetry_instrumentation_flask-0.61b0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-psycopg2==0.61b0 (from azure-monitor-opentelemetry)
#   Downloading opentelemetry_instrumentation_psycopg2-0.61b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation-requests==0.61b0 (from azure-monitor-opentelemetry)
#   Downloading opentelemetry_instrumentation_requests-0.61b0-py3-none-any.whl.metadata (2.7 kB)
# Collecting opentelemetry-instrumentation-urllib==0.61b0 (from azure-monitor-opentelemetry)
#   Downloading opentelemetry_instrumentation_urllib-0.61b0-py3-none-any.whl.metadata (3.5 kB)
# Collecting opentelemetry-instrumentation-urllib3==0.61b0 (from azure-monitor-opentelemetry)
#   Downloading opentelemetry_instrumentation_urllib3-0.61b0-py3-none-any.whl.metadata (4.2 kB)
# Collecting opentelemetry-instrumentation-logging==0.61b0 (from azure-monitor-opentelemetry)
#   Downloading opentelemetry_instrumentation_logging-0.61b0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-resource-detector-azure<1.0.0,>=0.1.5 (from azure-monitor-opentelemetry)
#   Downloading opentelemetry_resource_detector_azure-0.1.5-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: opentelemetry-api~=1.12 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-instrumentation-django==0.61b0->azure-monitor-opentelemetry) (1.39.1)
# Collecting opentelemetry-instrumentation-wsgi==0.61b0 (from opentelemetry-instrumentation-django==0.61b0->azure-monitor-opentelemetry)
#   Downloading opentelemetry_instrumentation_wsgi-0.61b0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation==0.61b0 (from opentelemetry-instrumentation-django==0.61b0->azure-monitor-opentelemetry)
#   Downloading opentelemetry_instrumentation-0.61b0-py3-none-any.whl.metadata (7.2 kB)
# Collecting opentelemetry-semantic-conventions==0.61b0 (from opentelemetry-instrumentation-django==0.61b0->azure-monitor-opentelemetry)
#   Downloading opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-util-http==0.61b0 (from opentelemetry-instrumentation-django==0.61b0->azure-monitor-opentelemetry)
#   Downloading opentelemetry_util_http-0.61b0-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-instrumentation-asgi==0.61b0 (from opentelemetry-instrumentation-fastapi==0.61b0->azure-monitor-opentelemetry)
#   Downloading opentelemetry_instrumentation_asgi-0.61b0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: packaging>=21.0 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-instrumentation-flask==0.61b0->azure-monitor-opentelemetry) (24.2)
# Collecting opentelemetry-instrumentation-dbapi==0.61b0 (from opentelemetry-instrumentation-psycopg2==0.61b0->azure-monitor-opentelemetry)
#   Downloading opentelemetry_instrumentation_dbapi-0.61b0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-instrumentation-urllib3==0.61b0->azure-monitor-opentelemetry) (1.17.0)
# Collecting opentelemetry-api~=1.12 (from opentelemetry-instrumentation-django==0.61b0->azure-monitor-opentelemetry)
#   Downloading opentelemetry_api-1.40.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-api~=1.12->opentelemetry-instrumentation-django==0.61b0->azure-monitor-opentelemetry) (8.5.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.61b0->opentelemetry-instrumentation-fastapi==0.61b0->azure-monitor-opentelemetry)
#   Downloading asgiref-3.11.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: azure-identity~=1.17 in /databricks/python3/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter~=1.0.0b52->azure-monitor-opentelemetry) (1.20.0)
# Collecting msrest>=0.6.10 (from azure-monitor-opentelemetry-exporter~=1.0.0b52->azure-monitor-opentelemetry)
#   Downloading msrest-0.7.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: psutil<8,>=5.9 in /databricks/python3/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter~=1.0.0b52->azure-monitor-opentelemetry) (5.9.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /databricks/python3/lib/python3.12/site-packages (from starlette<0.51.0,>=0.40.0->fastapi) (4.7.0)
# Requirement already satisfied: sniffio>=1.1 in /databricks/python3/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi) (1.3.0)
# Requirement already satisfied: cryptography>=2.5 in /databricks/python3/lib/python3.12/site-packages (from azure-identity~=1.17->azure-monitor-opentelemetry-exporter~=1.0.0b52->azure-monitor-opentelemetry) (44.0.1)
# Requirement already satisfied: msal>=1.30.0 in /databricks/python3/lib/python3.12/site-packages (from azure-identity~=1.17->azure-monitor-opentelemetry-exporter~=1.0.0b52->azure-monitor-opentelemetry) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /databricks/python3/lib/python3.12/site-packages (from azure-identity~=1.17->azure-monitor-opentelemetry-exporter~=1.0.0b52->azure-monitor-opentelemetry) (1.3.1)
# Requirement already satisfied: isodate>=0.6.0 in /databricks/python3/lib/python3.12/site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter~=1.0.0b52->azure-monitor-opentelemetry) (0.7.2)
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter~=1.0.0b52->azure-monitor-opentelemetry)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: cffi>=1.12 in /databricks/python3/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity~=1.17->azure-monitor-opentelemetry-exporter~=1.0.0b52->azure-monitor-opentelemetry) (1.17.1)
# Requirement already satisfied: zipp>=3.20 in /databricks/python3/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.12->opentelemetry-instrumentation-django==0.61b0->azure-monitor-opentelemetry) (3.21.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /databricks/python3/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity~=1.17->azure-monitor-opentelemetry-exporter~=1.0.0b52->azure-monitor-opentelemetry) (2.10.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter~=1.0.0b52->azure-monitor-opentelemetry) (3.2.2)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity~=1.17->azure-monitor-opentelemetry-exporter~=1.0.0b52->azure-monitor-opentelemetry) (2.21)
# Downloading structlog-26.1.0-py3-none-any.whl (73 kB)
# Downloading azure_monitor_opentelemetry-1.8.8-py3-none-any.whl (41 kB)
# Downloading opentelemetry_instrumentation_django-0.61b0-py3-none-any.whl (20 kB)
# Downloading opentelemetry_instrumentation_fastapi-0.61b0-py3-none-any.whl (13 kB)
# Downloading opentelemetry_instrumentation_flask-0.61b0-py3-none-any.whl (15 kB)
# Downloading opentelemetry_instrumentation_logging-0.61b0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_instrumentation_psycopg2-0.61b0-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation_requests-0.61b0-py3-none-any.whl (14 kB)
# Downloading opentelemetry_instrumentation_urllib-0.61b0-py3-none-any.whl (13 kB)
# Downloading opentelemetry_instrumentation_urllib3-0.61b0-py3-none-any.whl (14 kB)
# Downloading opentelemetry_sdk-1.40.0-py3-none-any.whl (141 kB)
# Downloading opentelemetry_api-1.40.0-py3-none-any.whl (68 kB)
# Downloading opentelemetry_instrumentation-0.61b0-py3-none-any.whl (33 kB)
# Downloading opentelemetry_instrumentation_asgi-0.61b0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_instrumentation_dbapi-0.61b0-py3-none-any.whl (14 kB)
# Downloading opentelemetry_instrumentation_wsgi-0.61b0-py3-none-any.whl (14 kB)
# Downloading opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl (231 kB)
# Downloading opentelemetry_util_http-0.61b0-py3-none-any.whl (9.3 kB)
# Downloading azure_core_tracing_opentelemetry-1.0.0b13-py3-none-any.whl (12 kB)
# Downloading azure_monitor_opentelemetry_exporter-1.0.0b53-py2.py3-none-any.whl (249 kB)
# Downloading opentelemetry_resource_detector_azure-0.1.5-py3-none-any.whl (14 kB)
# Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
# Downloading asgiref-3.11.1-py3-none-any.whl (24 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Installing collected packages: structlog, opentelemetry-util-http, asgiref, requests-oauthlib, opentelemetry-api, opentelemetry-semantic-conventions, msrest, azure-core-tracing-opentelemetry, opentelemetry-sdk, opentelemetry-instrumentation, opentelemetry-resource-detector-azure, opentelemetry-instrumentation-wsgi, opentelemetry-instrumentation-urllib3, opentelemetry-instrumentation-urllib, opentelemetry-instrumentation-requests, opentelemetry-instrumentation-logging, opentelemetry-instrumentation-dbapi, opentelemetry-instrumentation-asgi, opentelemetry-instrumentation-psycopg2, opentelemetry-instrumentation-flask, opentelemetry-instrumentation-fastapi, opentelemetry-instrumentation-django, azure-monitor-opentelemetry-exporter, azure-monitor-opentelemetry
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.39.1
#     Not uninstalling opentelemetry-api at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b97bfee-3351-40bc-b2aa-a4c98aba5583
#     Can't uninstall 'opentelemetry-api'. No files were found to uninstall.
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.60b1
#     Not uninstalling opentelemetry-semantic-conventions at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b97bfee-3351-40bc-b2aa-a4c98aba5583
#     Can't uninstall 'opentelemetry-semantic-conventions'. No files were found to uninstall.
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.39.1
#     Not uninstalling opentelemetry-sdk at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b97bfee-3351-40bc-b2aa-a4c98aba5583
#     Can't uninstall 'opentelemetry-sdk'. No files were found to uninstall.
# Successfully installed asgiref-3.11.1 azure-core-tracing-opentelemetry-1.0.0b13 azure-monitor-opentelemetry-1.8.8 azure-monitor-opentelemetry-exporter-1.0.0b53 msrest-0.7.1 opentelemetry-api-1.40.0 opentelemetry-instrumentation-0.61b0 opentelemetry-instrumentation-asgi-0.61b0 opentelemetry-instrumentation-dbapi-0.61b0 opentelemetry-instrumentation-django-0.61b0 opentelemetry-instrumentation-fastapi-0.61b0 opentelemetry-instrumentation-flask-0.61b0 opentelemetry-instrumentation-logging-0.61b0 opentelemetry-instrumentation-psycopg2-0.61b0 opentelemetry-instrumentation-requests-0.61b0 opentelemetry-instrumentation-urllib-0.61b0 opentelemetry-instrumentation-urllib3-0.61b0 opentelemetry-instrumentation-wsgi-0.61b0 opentelemetry-resource-detector-azure-0.1.5 opentelemetry-sdk-1.40.0 opentelemetry-semantic-conventions-0.61b0 opentelemetry-util-http-0.61b0 requests-oauthlib-2.0.0 structlog-26.1.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import os

 

import sys

 

import time

 

import uuid

 

import logging

 

import threading

 

import asyncio

 

import structlog

 

import uvicorn

 

from fastapi import FastAPI, status, HTTPException

 

from pydantic import BaseModel, Field


# ─── NEW: AZURE MONITOR PIPELINE CONFIGURATION ──────────────────────

 

from azure.monitor.opentelemetry import configure_azure_monitor


# Paste your copied string here (or use databricks secrets utility)

 

AZURE_CONN_STR = "InstrumentationKey=xxxx-xxxx-xxxx;IngestionEndpoint=https://..."


configure_azure_monitor(

 

    connection_string=AZURE_CONN_STR,

 

    logger_name="fastapi_routing_app" # Isolates app metrics from underlying SDK trace logs

 

)

 

# ─────────────────────────────────────────────────────────────────────


# 1. Structured Logging Configuration

 

logging.basicConfig(format="%(message)s", stream=sys.stdout, level=logging.INFO)

 

structlog.reset_defaults()

 

structlog.configure(

 

    processors=[

 

        structlog.stdlib.add_log_level,

 

        structlog.processors.TimeStamper(fmt="iso"),

 

        structlog.processors.JSONRenderer() # Log Analytics can naturally parse this JSON string

 

    ],

 

    context_class=dict,

 

    logger_factory=structlog.stdlib.LoggerFactory(),

 

    wrapper_class=structlog.stdlib.BoundLogger,

 

    cache_logger_on_first_use=True,

 

)

 

logger = structlog.get_logger("fastapi_routing_app")


# 2. FastAPI Application Setup

 

app = FastAPI(title="Connected Azure Log Analytics App")


class TargetRequest(BaseModel):

 

    user_name: str

 

    payload: dict


def run_ml_inference(data: dict) -> dict:

 

    logger.info("Starting ML model execution...", approach="neural_network_inference")

 

    time.sleep(0.150)

 

    return {"predicted_class": 0, "confidence": 0.94}


async def run_simple_pipeline(data: dict) -> dict:

 

    logger.info("Executing standard database processing pipeline...")

 

    return {"status": "processed"}


@app.post("/execute", status_code=status.HTTP_200_OK)

 

async def route_user_request(request: TargetRequest):

 

    user_name = request.user_name

 

    # Explicit logging context tracking

 

    log = logger.bind(user_name=user_name, request_id=str(uuid.uuid4()))


    if "ml_user" in user_name:

 

        log.info("Routing request to ML inference pool")

 

        result = await asyncio.to_thread(run_ml_inference, request.payload)

 

        log.info("ML inference successfully completed")

 

        return {"routing": "ml_pipeline", "result": result}

 

    elif "db_user" in user_name:

 

        log.info("Routing request to standard database function")

 

        result = await run_simple_pipeline(request.payload)

 

        log.info("Database execution successfully completed")

 

        return {"routing": "database_pipeline", "result": result}

 

    else:

 

        raise HTTPException(status_code=400, detail="Invalid user naming convention.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <command-7931318275148186>, line 58
#      51 # Paste your copied string here (or use databricks secrets utility)
#      55 AZURE_CONN_STR = "InstrumentationKey=xxxx-xxxx-xxxx;IngestionEndpoint=https://..."
# ---> 58 configure_azure_monitor(
#      59
#      60
#      61
#      62     connection_string=AZURE_CONN_STR,
#      63
#      64
#      65
#      66     logger_name="fastapi_routing_app" # Isolates app metrics from underlying SDK trace logs
#      67
#      68
#      69
#      70 )
#      74 # ─────────────────────────────────────────────────────────────────────
#      75
#      76
#      77 # 1. Structured Logging Configuration
#      81 logging.basicConfig(format="%(message)s", stream=sys.stdout, level=logging.INFO)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b97bfee-3351-40bc-b2aa-a4c98aba5583/lib/python3.12/site-packages/azure/monitor/opentelemetry/_configure.py:155, in configure_azure_monitor(**kwargs)
#     150 # Set up metrics pipeline
#     151 # Set up metrics with Performance Counters before _PerformanceCountersSpanProcessor and
#     152 # _PerformanceCountersLogRecordProcessor. This avoids a circular dependency in the case that Performance Counter
#     153 # setup produces a log.
#     154 if not disable_metrics:
# --> 155     _setup_metrics(configurations)
#     157 # Set up live metrics
#     158 if enable_live_metrics_config:
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b97bfee-3351-40bc-b2aa-a4c98aba5583/lib/python3.12/site-packages/azure/monitor/opentelemetry/_configure.py:301, in _setup_metrics(configurations)
#     299 readers: list[MetricReader] = configurations[METRIC_READERS_ARG]  # type: ignore
#     300 enable_performance_counters_config = configurations[ENABLE_PERFORMANCE_COUNTERS_ARG]
# --> 301 metric_exporter = AzureMonitorMetricExporter(**configurations)
#     302 readers.append(PeriodicExportingMetricReader(metric_exporter))
#     303 meter_provider = MeterProvider(
#     304     metric_readers=readers,
#     305     resource=resource,
#     306     views=views,
#     307 )
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b97bfee-3351-40bc-b2aa-a4c98aba5583/lib/python3.12/site-packages/azure/monitor/opentelemetry/exporter/export/metrics/_exporter.py:86, in AzureMonitorMetricExporter.__init__(self, **kwargs)
#      84 self._is_customer_sdkstats = kwargs.get("is_customer_sdkstats", False)
#      85 self._metrics_to_log_analytics = self._determine_metrics_to_log_analytics()
# ---> 86 BaseExporter.__init__(self, **kwargs)
#      87 MetricExporter.__init__(
#      88     self,
#      89     preferred_temporality=APPLICATION_INSIGHTS_METRIC_TEMPORALITIES,  # type: ignore
#      90     preferred_aggregation=kwargs.get("preferred_aggregation"),  # type: ignore
#      91 )
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b97bfee-3351-40bc-b2aa-a4c98aba5583/lib/python3.12/site-packages/azure/monitor/opentelemetry/exporter/export/_base.py:111, in BaseExporter.__init__(self, **kwargs)
#     100 def __init__(self, **kwargs: Any) -> None:
#     101     """Azure Monitor base exporter for OpenTelemetry.
#     102
#     103     :keyword str api_version: The service API version used. Defaults to latest.
#    (...)
#     109     :rtype: None
#     110     """
# --> 111     parsed_connection_string = ConnectionStringParser(kwargs.get("connection_string"))
#     113     # TODO: Uncomment configuration changes once testing is completed
#     114     # Get the configuration manager
#     115     # self._configuration_manager = get_configuration_manager()
#     117     self._api_version = kwargs.get("api_version") or _SERVICE_API_LATEST
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b97bfee-3351-40bc-b2aa-a4c98aba5583/lib/python3.12/site-packages/azure/monitor/opentelemetry/exporter/_connection_string_parser.py:44, in ConnectionStringParser.__init__(self, connection_string)
#      42 self.application_id = ""
#      43 self._initialize()
# ---> 44 self._validate_instrumentation_key()
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b97bfee-3351-40bc-b2aa-a4c98aba5583/lib/python3.12/site-packages/azure/monitor/opentelemetry/exporter/_connection_string_parser.py:109, in ConnectionStringParser._validate_instrumentation_key(self)
#     107 match = uuid_regex_pattern.match(self.instrumentation_key)
#     108 if not match:
# --> 109     raise ValueError("Invalid instrumentation key. It should be a valid UUID.")
#
# ValueError: Invalid instrumentation key. It should be a valid UUID.
